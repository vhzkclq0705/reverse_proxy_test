# %%
import pandas as pd

# %%
df = pd.read_csv("docker_stats.csv")
df['Timestamp'] = pd.to_datetime(df['Timestamp'], unit='s')

# %%
df
# Out:
#                Timestamp     Container                        Name  \
# 0    2025-02-27 02:19:23  3919cba37f82  reverse_proxy_test-cache-1
# 1    2025-02-27 02:19:23  1c40b1ca865c     reverse_proxy_test-lb-1
# 2    2025-02-27 02:19:23  8170c86feda3    reverse_proxy_test-api-1
# 3    2025-02-27 02:19:35  3919cba37f82  reverse_proxy_test-cache-1
# 4    2025-02-27 02:19:35  1c40b1ca865c     reverse_proxy_test-lb-1
# ...                  ...           ...                         ...
# 1345 2025-02-27 03:51:08  1c40b1ca865c     reverse_proxy_test-lb-1
# 1346 2025-02-27 03:51:08  8170c86feda3    reverse_proxy_test-api-1
# 1347 2025-02-27 04:43:28  3919cba37f82  reverse_proxy_test-cache-1
# 1348 2025-02-27 04:43:28  1c40b1ca865c     reverse_proxy_test-lb-1
# 1349 2025-02-27 04:43:28  8170c86feda3    reverse_proxy_test-api-1
#
#                 ID CPUPerc             MemUsage MemPerc        NetIO  \
# 0     3919cba37f82   0.00%     19.7MiB / 400MiB   4.92%  1.23kB / 0B
# ...
